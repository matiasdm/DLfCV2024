# %% [markdown]
# # TP Lecture 2: Introduction to digital images
#
# We will learn how to manipulate and visualize digital images. We will get familiar with main image formats and state-of-the-art image processing libraries including: OpenCV, scikit-image, Mahotas, Matplotlib, and Pillow.

# %%
# !pip install -r requirements.txt
# Out:
# zsh:1: /Users/matiasdimartino/Dropbox/Work/ucu/teaching/ComputerVision/cv-labs/.venv/bin/pip: bad interpreter: /Users/matiasdimartino/Dropbox/Work/ucu/teaching/ComputerVision/Labs/cv/.venv/bin/python: no such file or directory
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 15.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 16.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 MB 18.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 22.8 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached scikit_image-0.22.0-cp310-cp310-macosx_10_9_x86_64.whl (13.9 MB)
# ...
#   Using cached mahotas-1.4.13-cp310-cp310-macosx_10_15_universal2.whl (2.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 22.4 MB/s eta 0:00:0000:0100:01
# ...

# %% [markdown]
# ## OpenCV

# %%
import cv2
import matplotlib.pyplot as plt
# Check cv2 version
print(cv2.__version__)
# Read and display a test image 
img = cv2.imread('data/test1.jpg')
# Out:
# 4.8.1

# %%
# TODO: show this image using matplotlib
# hint: open CV represent images as BGR, but matplotlib uses RGB
# ---------------------------------------- #
# Ex1 (a):
# TODO
# ---------------------------------------- #

# %%
# ---------------------------------------- #
# Ex1 (b):
# (b1) Estimate the number of bytes img takes if ist data type is uint8
estimated_array_size = #TODO
print(f'The estimated array size is {estimated_array_size:2.1e} bytes')
# (b2) Print the actual memory usage of the array 
array_size = #TODO
print(f'The image is {array_size:2.1e} bytes')
# (b3) Is test1.jpg taking the same space on disk? if not explain the difference. 
# ---------------------------------------- #
# Out:
# The estimated array size is 7.2e+07 bytes
# The image is 7.2e+07 bytes

# %% [markdown]
# ## Scikit-image

# %%
import skimage as ski
# Read the image
original = ski.io.imread('data/test4.jpg')

# %%
# Display the original image and the grayscale one
from skimage.color import rgb2gray
grayscale = rgb2gray(original)
# ----------------------------------- #
# Ex2-a: Define the grayscale image by averaging the RGB channels.
avg_grayscale = #TODO
# ----------------------------------- #

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
ax = axes.ravel()
ax[0].imshow(original)
ax[0].set_title("Original")
ax[1].imshow(grayscale, cmap=plt.cm.gray)
ax[1].set_title("Grayscale by skimage")
ax[2].imshow(avg_grayscale, cmap=plt.cm.gray)
ax[2].set_title("Grayscale by averaging")
fig.tight_layout()
plt.show()

# ------------------------------------ # 
# Ex2-b: How is skimage's grayscale different from the one you defined?
# Solucion: skimage's grayscale is a weighted average of the RGB channels
# Y = 0.2125 R + 0.7154 G + 0.0721 B
# ------------------------------------ #

# %% [markdown]
# ## Mahotas

# %%
import mahotas as mh
import numpy as np
image = mh.imread('data/test1.jpg')  # read image
image = image.mean(axis=2)  # convert to grayscale by channel average   
image = image.astype(np.uint8)  # convert to uint8
# ------------------------------------ #
# Ex3: Use mahotas tools to compute otsu thresholding and display the result
#TODO
# ------------------------------------ #

# %% [markdown]
# ## Pillow

# %%
from PIL import Image
original = Image.open('data/test3.jpg')
# Print the image format, size and mode
print(original.format, original.size, original.mode)

# ----------------------------------- #
# Ex4: Use Pillow to rotate the image 90 degrees and display the result
#TODO
# ----------------------------------- # 

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
ax = axes.ravel()
ax[0].imshow(original)
ax[0].set_title("Original")
ax[1].imshow(rotated, cmap=plt.cm.gray)
ax[1].set_title("Rotated")
fig.tight_layout()
plt.show()
# Out:
# JPEG (4016, 4038) RGB

# %% [markdown]
# #

# %% [markdown]
# ## Check and install vpv
# https://github.com/kidanger/vpv

# %%
# ----------------------------------- #
# Ex5: Install vpv and visualize images like a pro ; ) 
# ----------------------------------- #
